# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import gtfb
import numpy as np

# %%
analysisfilt = gtfb.FIR()
synthesisfilt = gtfb.FIR(reversetime=True)

# %%
testsig = np.zeros(5000)
testsig[100] = 1
sig1 = analysisfilt.process_single(testsig, 5)
sig2 = synthesisfilt.process_single(testsig, 5)

# %%
_=plt.plot(sig2)
